# %%
#importing the required libraries to use within the analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go

# %%
#importing the data which we will use 
order_details = pd.read_csv('order_details.csv',encoding="utf-8")
pizzas = pd.read_csv('pizzas.csv',encoding='utf-8')
orders = pd.read_csv('orders.csv',encoding='utf-8')
pizza_types = pd.read_csv('pizza_types.csv',encoding='latin1')

# %%
#Exploring the datasets to see the relationships between the different datasets to be able to work on Merging it together.
order_details.head()
pizzas.head()
orders.head()
pizza_types.head()
# Out:
#   pizza_type_id                          name category  \
# 0       bbq_ckn    The Barbecue Chicken Pizza  Chicken
# 1      cali_ckn  The California Chicken Pizza  Chicken
# 2   ckn_alfredo     The Chicken Alfredo Pizza  Chicken
# 3     ckn_pesto       The Chicken Pesto Pizza  Chicken
# 4    southw_ckn   The Southwest Chicken Pizza  Chicken
#
#                                          ingredients
# 0  Barbecued Chicken, Red Peppers, Green Peppers,...
# 1  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
# 2  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 3  Chicken, Tomatoes, Red Peppers, Spinach, Garli...
# 4  Chicken, Tomatoes, Red Peppers, Red Onions, Ja...

# %%
#Exploring if there is any missing data to work on it
# order_details.info()
# pizzas.info()
# orders.info()
pizza_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_type_id  32 non-null     object
#  1   name           32 non-null     object
#  2   category       32 non-null     object
#  3   ingredients    32 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
#Merging the datasets into one to work the analysis on it 
df = pd.merge(order_details,pizzas, on = 'pizza_id')
df = pd.merge(df, orders, on = 'order_id')
df=pd.merge(df,pizza_types,on = "pizza_type_id")

# %%
#Building a column to have the total price of the order
df.rename(columns ={'price':'price_of_one_pizza'},inplace = True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_details_id    48620 non-null  int64
#  1   order_id            48620 non-null  int64
#  2   pizza_id            48620 non-null  object
#  3   quantity            48620 non-null  int64
#  4   pizza_type_id       48620 non-null  object
#  5   size                48620 non-null  object
#  6   price_of_one_pizza  48620 non-null  float64
#  7   date                48620 non-null  object
#  8   time                48620 non-null  object
#  9   name                48620 non-null  object
#  10  category            48620 non-null  object
#  11  ingredients         48620 non-null  object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 4.8+ MB
#    order_details_id  order_id    pizza_id  quantity pizza_type_id size  \
# 0                 1         1  hawaiian_m         1      hawaiian    M
# 1               179        77  hawaiian_m         1      hawaiian    M
# 2               357       146  hawaiian_m         1      hawaiian    M
# 3               389       163  hawaiian_m         1      hawaiian    M
# 4               568       247  hawaiian_m         1      hawaiian    M
#
#    price_of_one_pizza        date      time                name category  \
# 0               13.25  2015-01-01  11:38:36  The Hawaiian Pizza  Classic
# 1               13.25  2015-01-02  12:22:46  The Hawaiian Pizza  Classic
# 2               13.25  2015-01-03  14:22:10  The Hawaiian Pizza  Classic
# 3               13.25  2015-01-03  16:54:54  The Hawaiian Pizza  Classic
# 4               13.25  2015-01-04  20:55:29  The Hawaiian Pizza  Classic
#
#                                 ingredients
# 0  Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Sliced Ham, Pineapple, Mozzarella Cheese
# 2  Sliced Ham, Pineapple, Mozzarella Cheese
# 3  Sliced Ham, Pineapple, Mozzarella Cheese
# 4  Sliced Ham, Pineapple, Mozzarella Cheese

# %%
df['total_price'] = df['quantity'] * df['price_of_one_pizza']

# %%
#to know the maximum quantity for one order 
df['quantity'].max()
# Out:
# 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48620 entries, 0 to 48619
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_details_id    48620 non-null  int64
#  1   order_id            48620 non-null  int64
#  2   pizza_id            48620 non-null  object
#  3   quantity            48620 non-null  int64
#  4   pizza_type_id       48620 non-null  object
#  5   size                48620 non-null  object
#  6   price_of_one_pizza  48620 non-null  float64
#  7   date                48620 non-null  object
#  8   time                48620 non-null  object
#  9   name                48620 non-null  object
#  10  category            48620 non-null  object
#  11  ingredients         48620 non-null  object
#  12  total_price         48620 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 5.2+ MB

# %%
import plotly.offline as py

# %%
import plotly.express as px
# To answer this question we will need to split the day, month, year from one column into 3 columns
day=[]
month=[]
year=[]
for i in df['date']:
    year.append(i[0:4])
    month.append(i[5:7])
    day.append(i[8:10])
df['day']=day
df['month']=month
df['year']=year

# %% [markdown]
# #### If we looked to this chart we will find that 31th day of the month is the lowest average of orders but that because it came 7 times only within the year and the rest days came 12 times
# #### so when we divided the number of orders of 31th we will get average = 142.3 so it will be the 5th day in the order

# %%
fig = px.line(df["day"].value_counts()/12)
fig.show()
# Out:
# <div>                            <div id="48c02290-9c7f-405e-aec8-f22bbffc3d6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48c02290-9c7f-405e-aec8-f22bbffc3d6c")) {                    Plotly.newPlot(                        "48c02290-9c7f-405e-aec8-f22bbffc3d6c",                        [{"hovertemplate":"variable=day<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"day","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"day","orientation":"v","showlegend":true,"x":["15","01","04","27","06","03","09","11","20","17","07","08","13","14","02","16","10","23","18","21","24","26","22","19","28","12","30","05","29","25","31"],"xaxis":"x","y":[153.66666666666666,148.5,147.75,146.91666666666666,139.41666666666666,138.33333333333334,138.0,137.91666666666666,137.5,137.41666666666666,137.25,137.16666666666666,136.91666666666666,136.91666666666666,135.33333333333334,134.08333333333334,133.41666666666666,132.91666666666666,132.41666666666666,130.0,128.83333333333334,125.33333333333333,123.66666666666667,121.91666666666667,120.83333333333333,120.25,119.91666666666667,118.91666666666667,113.41666666666667,103.75,83.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7 ...

# %% [markdown]
# ### Now we will work on finding the busiest day in the year ever

# %%
df['date'].value_counts()
# Out:
# 2015-11-26    261
# 2015-11-27    259
# 2015-10-15    258
# 2015-07-04    233
# 2015-07-03    207
#              ...
# 2015-12-27     87
# 2015-11-22     82
# 2015-12-29     77
# 2015-03-22     76
# 2015-12-30     73
# Name: date, Length: 358, dtype: int64

# %% [markdown]
# #### By seeing the result above we found that the busiest days are the 26th, 27th of November, and the 15th of October

# %%
df[df['date']=='2015-11-26'].time.value_counts()
# Out:
# 12:40:36    13
# 14:58:08     5
# 12:11:45     4
# 12:03:28     4
# 15:39:39     4
#             ..
# 21:42:04     1
# 21:07:49     1
# 21:18:42     1
# 16:14:55     1
# 12:03:31     1
# Name: time, Length: 113, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48620 entries, 0 to 48619
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_details_id    48620 non-null  int64
#  1   order_id            48620 non-null  int64
#  2   pizza_id            48620 non-null  object
#  3   quantity            48620 non-null  int64
#  4   pizza_type_id       48620 non-null  object
#  5   size                48620 non-null  object
#  6   price_of_one_pizza  48620 non-null  float64
#  7   date                48620 non-null  object
#  8   time                48620 non-null  object
#  9   name                48620 non-null  object
#  10  category            48620 non-null  object
#  11  ingredients         48620 non-null  object
#  12  total_price         48620 non-null  float64
#  13  day                 48620 non-null  object
#  14  month               48620 non-null  object
#  15  year                48620 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 6.3+ MB

# %%
df['history'] = df['date']+" "+df['time']

# %%
no_orders_in_peak = df[df['time'] < '15:00:00' ].value_counts().sum()
no_orders_in_peak_percent = (df[df['time'] < '15:00:00' ].value_counts().sum() / 48620)*100

print("The total number of pizzas during the peak period is {} pizzas which during the first 7 hours of the day only and which represents {:.0f}% of the total day orders quantity".format(no_orders_in_peak,no_orders_in_peak_percent))
# Out:
# The total number of pizzas during the peak period is 18960 pizzas which during the first 7 hours of the day only and which represents 39% of the total day orders quantity

# %%
df.pizza_id.value_counts()
# Out:
# big_meat_s        1811
# thai_ckn_l        1365
# five_cheese_l     1359
# four_cheese_l     1273
# classic_dlx_m     1159
#                   ...
# mexicana_s         160
# calabrese_s         99
# ckn_alfredo_s       96
# green_garden_l      94
# the_greek_xxl       28
# Name: pizza_id, Length: 91, dtype: int64

# %% [markdown]
# #### The best pizza in our sales is SMALL big meat pizza

# %% [markdown]
# #### The worst pizza in our sales is The XXL Greek pizza

# %%
avg_order_price = df['total_price'].mean()

print("Our average order value is {:.2f}$".format(avg_order_price))
# Out:
# Our average order value is 16.82$

# %% [markdown]
# ##### To answer the question of how can we utilize the seats
# ##### after internet search I found that the average time of pizza making is 8-15 mins and to eat it 8-15 mins so if there are customers in the resturant they will remain for 30 mins maximum
# ##### so we will look at the peak periods to know the maximum number of customers to know how we will work on chairs arrangement.

# %%
(df[df['date']=='2015-11-26'][df.time < "13:00:00" ][df.time > "12:10:00" ].time.value_counts()).sum()
# Out:
# C:\Users\omarm\AppData\Local\Temp\ipykernel_13344\3720964242.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# 29

# %% [markdown]
# #### The number of the orders within the peak period is 29 order
# #### So we will need to at least 58 chair to satisfy the number of orders that will be made by at leat two persons together

# %% [markdown]
# ### ---------------------------------------------------

# %% [markdown]
# ### In the rest of the code we will work on some analysis that may help us know the taste of the customers and how can we play with to earn more money

# %%
#this code will be used to split each pizza ingredients into one by one to be able to specify the most used ingredient  
ingredient =[]
for i in df['ingredients']:
    ingredient.append(i)
ingred =[]
for i in ingredient:
    ing = i.split(',')
    ingred.append(ing)
alone = []
for t in ingred:
    for i in t:
        alone.append(i)

# %%
alone = pd.DataFrame(alone)
alone.value_counts()[0:20]
# Out:
#  Garlic               27422
#  Tomatoes             23694
#  Red Onions           19547
#  Red Peppers          16284
# Chicken                8443
#  Mushrooms             8114
#  Mozzarella Cheese     6605
#  Pepperoni             6542
#  Green Olives          6174
#  Artichokes            5682
#  Jalapeno Peppers      5643
# Spinach                5239
#  Green Peppers         5224
#  Spinach               4773
#  Feta Cheese           4748
#  Pineapple             4685
# Pepperoni              3758
# Mozzarella Cheese      3728
#  Asiago Cheese         3342
#  Chipotle Sauce        3341
# dtype: int64

# %%
alone['ingredient_name']= alone

# %%
alone[alone['ingredient_name'] == 'Pepperoni'].value_counts().sum() + alone[alone['ingredient_name'] == ' Pepperoni'].value_counts().sum()
# Out:
# 10300

# %%
alone[alone['ingredient_name'] == 'Chicken'].value_counts().sum() + alone[alone['ingredient_name'] == ' Chicken'].value_counts().sum()
# Out:
# 8443

# %% [markdown]
# #### If we looked to the ingredients we will see that customers like the Pepperoni more that Chicken and in general we will find that the vegetables play a main role in the pizza industry
# #### So we must work on get more supply from these vegetables (Garlic - Tomatoes - Red Onions - Red Peppers ) to fullfill our need

# %%
table = pd.pivot_table(df,index=df['total_price'],
                    columns=df['pizza_id'], aggfunc=np.sum)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
table.describe().max().sort_values(ascending=False)
# Out:
#                     pizza_id
# order_details_id    big_meat_s        41763841.00
#                     thai_ckn_l        32884614.00
#                     five_cheese_l     30672358.00
#                     four_cheese_l     30059361.00
#                     classic_dlx_m     28534948.00
#                     spicy_ital_l      25727019.00
#                     hawaiian_s        24197617.00
#                     southw_ckn_l      23535665.00
#                     bbq_ckn_l         22518030.00
#                     pepperoni_m       21574281.00
#                     hawaiian_l        21501004.00
#                     cali_ckn_l        21346821.00
#                     ital_supr_m       21263014.00
#                     bbq_ckn_m         21156773.00
#                     cali_ckn_m        21085130.00
#                     mexicana_l        20141073.00
#                     classic_dlx_s     18916487.00
# order_id            big_meat_s        18384677.00
# order_details_id    ital_supr_l       17809248.00
#                     pepperoni_s       17592953.00
#                     sicilian_s        17206008.00
#                     ital_cpcllo_l     17190559.00
#                     ckn_alfredo_m     16818866.00
#                     pepperoni_l       16429795.00
#                     peppr_salami_l    15973871.00
#                     veggie_veg_m      14783187.00
#                     sicilian_l        14518755.00
# order_id            thai_ckn_l        14474659.00
# order_details_id    green_garden_s    14151596.00
#                     prsc_argla_m      14045054.00
#                     spinach_fet_m     13847709.00
#                     pep_msh_pep_s     13580314.00
# order_id            five_cheese_l     13503604.00
# order_details_id    four_cheese_m     13498487.00
#                     calabrese_m       13355252.00
#                     sicilian_m        13352178.00
# order_id            four_cheese_l     13231095.00
# order_details_id    southw_ckn_m      13036121.00
#                     napolitana_l      13030391.00
#                     the_greek_xl      12607937.00
# order_id            classic_dlx_m     12562169.00
# order_details_id    cali_ckn_s        12157537.00
#                     thai_ckn_s        11618100.00
#                     classic_dlx_l     11608174.00
#                     brie_carre_s      11485661.00
#                     hawaiian_m        11473006.00
#                     bbq_ckn_s         11418373.00
#                     ital_veggie_m     11380832.00
# order_id            spicy_ital_l      11323986.00
# order_details_id    thai_ckn_m        11318171.00
#                     napolitana_s      11292014.00
#                     mexicana_m        11124884.00
# order_id            hawaiian_s        10651437.00
# order_details_id    napolitana_m      10637754.00
#                     veggie_veg_s      10622008.00
#                     spinach_fet_l     10477104.00
# order_id            southw_ckn_l      10360430.00
# order_details_id    peppr_salami_m    10329070.00
#                     veggie_veg_l      10117419.00
#                     spicy_ital_s      10069448.00
#                     prsc_argla_s       9914506.00
# order_id            bbq_ckn_l          9912733.00
# order_details_id    prsc_argla_l       9857620.00
#                     spinach_fet_s      9824022.00
#                     spin_pesto_s       9803878.00
#                     spicy_ital_m       9599114.00
# order_id            pepperoni_m        9497312.00
#                     hawaiian_l         9464894.00
#                     cali_ckn_l         9396929.00
#                     ital_supr_m        9359060.00
# order_details_id    pep_msh_pep_m      9349036.00
#                     spinach_supr_s     9334630.00
# order_id            bbq_ckn_m          9313254.00
# order_details_id    soppressata_l      9308157.00
# order_id            cali_ckn_m         9281887.00
# order_details_id    pep_msh_pep_l      9243687.00
#                     ital_cpcllo_m      9167715.00
#                     ckn_pesto_l        9132359.00
# order_id            mexicana_l         8865444.00
# order_details_id    mediterraneo_l     8797894.00
#                     southw_ckn_s       8793758.00
# order_id            classic_dlx_s      8326753.00
# order_details_id    peppr_salami_s     8069018.00
# order_id            ital_supr_l        7840146.00
#                     pepperoni_s        7746208.00
#                     sicilian_s         7574771.00
#                     ital_cpcllo_l      7567548.00
#                     ckn_alfredo_m      7404221.00
# order_details_id    the_greek_s        7301821.00
#                     spin_pesto_m       7238397.00
#                     mediterraneo_s     7238078.00
# order_id            pepperoni_l        7233981.00
# order_details_id    ckn_pesto_s        7096898.00
#                     ital_cpcllo_s      7088300.00
#                     ckn_pesto_m        7077693.00
#                     soppressata_s      7056637.00
#                     ital_veggie_s      7039362.00
# order_id            peppr_salami_l     7030371.00
# order_details_id    green_garden_m     7029695.00
#                     calabrese_l        6899372.00
#                     mediterraneo_m     6895731.00
#                     the_greek_m        6688985.00
#                     soppressata_m      6572341.00
# order_id            veggie_veg_m       6506200.00
# order_details_id    spinach_supr_l     6474219.00
#                     spinach_supr_m     6446583.00
#                     the_greek_l        6393055.00
# order_id            sicilian_l         6390778.00
# order_details_id    spin_pesto_l       6331932.00
# order_id            green_garden_s     6230439.00
#                     prsc_argla_m       6183583.00
#                     spinach_fet_m      6096213.00
#                     pep_msh_pep_s      5978994.00
#                     four_cheese_m      5942254.00
#                     calabrese_m        5879895.00
#                     sicilian_m         5877224.00
#                     southw_ckn_m       5738674.00
#                     napolitana_l       5737448.00
#                     the_greek_xl       5549425.00
#                     cali_ckn_s         5352492.00
#                     thai_ckn_s         5114739.00
#                     classic_dlx_l      5108940.00
#                     brie_carre_s       5056682.00
#                     hawaiian_m         5050258.00
#                     bbq_ckn_s          5026391.00
#                     ital_veggie_m      5009148.00
#                     thai_ckn_m         4981381.00
#                     napolitana_s       4970568.00
#                     mexicana_m         4896035.00
#                     napolitana_m       4683581.00
#                     veggie_veg_s       4674735.00
# order_details_id    ital_supr_s        4665303.00
# order_id            spinach_fet_l      4611921.00
# order_details_id    ckn_alfredo_l      4552602.00
# order_id            peppr_salami_m     4546398.00
# order_details_id    ital_veggie_l      4464743.00
# order_id            veggie_veg_l       4452792.00
#                     spicy_ital_s       4431869.00
#                     prsc_argla_s       4365179.00
#                     prsc_argla_l       4339101.00
#                     spinach_fet_s      4324092.00
#                     spin_pesto_s       4315505.00
#                     spicy_ital_m       4225297.00
#                     pep_msh_pep_m      4115743.00
#                     spinach_supr_s     4110089.00
#                     soppressata_l      4096600.00
#                     pep_msh_pep_l      4068815.00
# order_details_id    mexicana_s         4061322.00
# order_id            ital_cpcllo_m      4035488.00
#                     ckn_pesto_l        4021469.00
#                     mediterraneo_l     3873110.00
#                     southw_ckn_s       3871982.00
#                     peppr_salami_s     3551809.00
#                     the_greek_s        3213834.00
#                     spin_pesto_m       3186735.00
#                     mediterraneo_s     3185459.00
#                     ckn_pesto_s        3123795.00
#                     ital_cpcllo_s      3120363.00
#                     ckn_pesto_m        3114940.00
#                     soppressata_s      3106302.00
#                     ital_veggie_s      3098801.00
#                     green_garden_m     3094925.00
#                     calabrese_l        3036602.00
#                     mediterraneo_m     3034755.00
#                     the_greek_m        2943731.00
#                     soppressata_m      2893594.00
#                     spinach_supr_l     2849825.00
#                     spinach_supr_m     2837125.00
#                     the_greek_l        2814278.00
#                     spin_pesto_l       2787040.00
# order_details_id    ckn_alfredo_s      2371054.00
#                     calabrese_s        2354591.00
#                     green_garden_l     2102594.00
# order_id            ital_supr_s        2053616.00
#                     ckn_alfredo_l      2004050.00
#                     ital_veggie_l      1965636.00
#                     mexicana_s         1788432.00
#                     ckn_alfredo_s      1043889.00
#                     calabrese_s        1036061.00
#                     green_garden_l      925693.00
# order_details_id    the_greek_xxl       640703.00
# order_id            the_greek_xxl       282061.00
# price_of_one_pizza  thai_ckn_l           27410.75
#                     five_cheese_l        24235.00
#                     spicy_ital_l         22161.00
#                     four_cheese_l        22078.50
#                     big_meat_s           20592.00
#                     southw_ckn_l         20127.50
#                     bbq_ckn_l            19567.25
#                     classic_dlx_m        18224.00
#                     cali_ckn_l           17948.75
#                     mexicana_l           16625.25
#                     bbq_ckn_m            15058.25
#                     ital_supr_l          15002.25
#                     ital_supr_m          14833.50
#                     cali_ckn_m           14807.00
#                     hawaiian_l           14421.00
#                     ital_cpcllo_l        14329.50
#                     peppr_salami_l       13778.00
#                     the_greek_xl         13668.00
#                     sicilian_l           11724.75
#                     ckn_alfredo_m        11574.25
#                     napolitana_l         11234.00
#                     pepperoni_m          11225.00
#                     brie_carre_s         11115.50
#                     pepperoni_l          10614.00
#                     hawaiian_s           10311.00
#                     veggie_veg_m         10000.00
#                     classic_dlx_l         9614.50
#                     prsc_argla_m          9438.00
#                     classic_dlx_s         9288.00
#                     sicilian_m            8905.00
#                     calabrese_m           8872.50
#                     spinach_fet_m         8864.00
#                     sicilian_s            8709.75
#                     spinach_fet_l         8687.25
#                     southw_ckn_m          8676.50
#                     prsc_argla_l          8549.00
#                     veggie_veg_l          8484.75
#                     four_cheese_m         8378.00
#                     soppressata_l         8237.75
#                     ital_veggie_m         8040.00
#                     ckn_pesto_l           7988.75
#                     thai_ckn_m            7822.25
#                     mediterraneo_l        7249.50
#                     mexicana_m            7184.00
#                     pepperoni_s           7088.25
#                     green_garden_s        7032.00
#                     peppr_salami_m        6930.00
#                     napolitana_m          6800.00
#                     pep_msh_pep_l         6615.00
#                     spicy_ital_m          6468.00
#                     ital_cpcllo_m         6304.00
#                     cali_ckn_s            6209.25
#                     pep_msh_pep_s         6182.00
#                     hawaiian_m            6134.75
#                     bbq_ckn_s             6043.50
#                     thai_ckn_s            6018.00
#                     spinach_supr_l        5747.75
#                     spin_pesto_l          5685.50
#                     pep_msh_pep_m         5582.50
#                     napolitana_s          5580.00
#                     calabrese_l           5508.00
#                     veggie_veg_s          5400.00
#                     the_greek_l           5227.50
#                     spinach_fet_s         5220.00
#                     prsc_argla_s          5200.00
#                     spicy_ital_s          4900.00
#                     spin_pesto_s          4875.00
#                     spinach_supr_s        4850.00
#                     green_garden_m        4768.00
#                     southw_ckn_s          4653.75
#                     spin_pesto_m          4620.00
#                     ckn_pesto_m           4556.00
#                     the_greek_m           4432.00
#                     soppressata_m         4422.00
#                     spinach_supr_m        4372.50
#                     mediterraneo_m        4272.00
#                     ital_veggie_l         3990.00
#                     peppr_salami_s        3925.00
#                     ckn_alfredo_l         3859.50
#                     ital_veggie_s         3812.25
#                     ckn_pesto_s           3723.00
#                     soppressata_s         3600.00
#                     ital_cpcllo_s         3576.00
#                     the_greek_s           3552.00
#                     mediterraneo_s        3444.00
#                     ital_supr_s           2400.00
#                     mexicana_s            1896.00
#                     green_garden_l        1883.25
# quantity            big_meat_s            1716.00
#                     thai_ckn_l            1321.00
#                     five_cheese_l         1310.00
#                     four_cheese_l         1230.00
# price_of_one_pizza  ckn_alfredo_s         1224.00
#                     calabrese_s           1212.75
# quantity            classic_dlx_m         1139.00
#                     spicy_ital_l          1068.00
# price_of_one_pizza  the_greek_xxl         1006.60
# quantity            hawaiian_s             982.00
#                     southw_ckn_l           970.00
#                     bbq_ckn_l              943.00
#                     ital_supr_m            899.00
#                     bbq_ckn_m              899.00
#                     pepperoni_m            898.00
#                     cali_ckn_m             884.00
#                     hawaiian_l             874.00
#                     cali_ckn_l             865.00
#                     mexicana_l             821.00
#                     classic_dlx_s          774.00
#                     pepperoni_s            727.00
#                     ital_supr_l            723.00
#                     sicilian_s             711.00
#                     ital_cpcllo_l          699.00
#                     pepperoni_l            696.00
#                     ckn_alfredo_m          691.00
#                     peppr_salami_l         664.00
#                     veggie_veg_m           625.00
#                     green_garden_s         586.00
#                     sicilian_l             579.00
#                     prsc_argla_m           572.00
#                     four_cheese_m          568.00
#                     pep_msh_pep_s          562.00
#                     spinach_fet_m          554.00
#                     napolitana_l           548.00
#                     sicilian_m             548.00
#                     calabrese_m            546.00
#                     the_greek_xl           536.00
#                     southw_ckn_m           518.00
#                     cali_ckn_s             487.00
#                     ital_veggie_m          480.00
#                     bbq_ckn_s              474.00
#                     thai_ckn_s             472.00
#                     brie_carre_s           470.00
#                     classic_dlx_l          469.00
#                     thai_ckn_m             467.00
#                     napolitana_s           465.00
#                     hawaiian_m             463.00
#                     veggie_veg_s           450.00
#                     mexicana_m             449.00
#                     spinach_fet_s          435.00
#                     spinach_fet_l          429.00
#                     napolitana_m           425.00
#                     peppr_salami_m         420.00
#                     veggie_veg_l           419.00
#                     prsc_argla_s           416.00
#                     prsc_argla_l           412.00
#                     soppressata_l          397.00
#                     ital_cpcllo_m          394.00
#                     spicy_ital_s           392.00
#                     spicy_ital_m           392.00
#                     spin_pesto_s           390.00
#                     spinach_supr_s         388.00
#                     pep_msh_pep_m          385.00
#                     ckn_pesto_l            385.00
#                     pep_msh_pep_l          378.00
#                     southw_ckn_s           365.00
#                     mediterraneo_l         358.00
#                     peppr_salami_s         314.00
#                     ital_veggie_s          299.00
#                     green_garden_m         298.00
#                     ital_cpcllo_s          298.00
#                     the_greek_s            296.00
#                     ckn_pesto_s            292.00
#                     soppressata_s          288.00
#                     mediterraneo_s         287.00
#                     spin_pesto_m           280.00
#                     the_greek_m            277.00
#                     spinach_supr_l         277.00
#                     spin_pesto_l           274.00
#                     ckn_pesto_m            272.00
#                     calabrese_l            272.00
#                     soppressata_m          268.00
#                     mediterraneo_m         267.00
#                     spinach_supr_m         265.00
#                     the_greek_l            255.00
#                     ital_supr_s            192.00
#                     ital_veggie_l          190.00
#                     ckn_alfredo_l          186.00
#                     mexicana_s             158.00
#                     calabrese_s             99.00
#                     ckn_alfredo_s           96.00
#                     green_garden_l          93.00
#                     the_greek_xxl           28.00
# dtype: float64

# %% [markdown]
# #### If we looked into the previous Pivot table we will find that the pizzas with Pepperoni "meat in general" have a bigger reputation than Chicken so we can increase our sales by providing
# #### other meat products that have pepperoni and bacon in it.

# %%
df['size'].value_counts()
# Out:
# L      18526
# M      15385
# S      14137
# XL       544
# XXL       28
# Name: size, dtype: int64

# %%
fig = px.histogram(df, x=df['size'])
fig.show()
# Out:
# <div>                            <div id="90d25b92-7190-42e3-a86f-a3efc8bb9194" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90d25b92-7190-42e3-a86f-a3efc8bb9194")) {                    Plotly.newPlot(                        "90d25b92-7190-42e3-a86f-a3efc8bb9194",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"size=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","L","M","M","M","S","L","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","S","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","M","M","L","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","M","M","M","S","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","L","M","M","M","M","M","M","M","S","M","L","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","M","S","M","M","M","M","M","M","M","S","L","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","L","M","M","M","M","M","L","M","M","M","M","L","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","S","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","M","M","M","M","S","L","M","S","M","M","M","M","S","M","M","M","M","L","M","M","M","M","L","M","M","M","M","M","M","M","M","M","M","M","S","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","M","M","M","M","M","M","M","S","M","M","M","M","M","M","M","S","M","S","M","M","M","S","M","M","M","M","M","M","M","M","L","M","M","M","S","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","S","M","M","M","M","M","M","M","L","M","S","M","M","M","M","S","M","M","M","M","M","M","M","M","M","M","M","M","L","M","M","S","M","M","M","M","M","M","S","L","S","L","L","S","L","S","S","L","L","S","L","S","S","L","L","L","L","S","S","L","S","L","L","S","S","L","S","S","L","S","L","S","S","S","L","L","L","S","L","L","S","L","S","S","L","S","L","S","L","L","L","L","L","L","S","S","S","S","S","L","S","L","S","S","S","S","S","L","L","L","L","S","L","S","S","L","L","L","L","L","L","S","S","L","S","S","S","S","L","L","S","S","S","S","L","L","L","L","L","S","S","S","S","S","L","L","L","L","S","L","L","S","L","L","S","S","L","L","L","S","S","L","S","S","L","L","S","L","L","S","L","L","S","S","S","S","L","L","S","S","S","L","L","L","S","S","S","L","S","S","L","S","L","L","L","L","S","L","S","L","S","L","L","S","S","L","S","L","S","L","S","L","S","L","S","L","L","L","L","L","L","L","S","S","S","S","L","S","S","L","L","S","S","S","S","L","L","S","S","L","S","S","S","L","S","L","L","L","S","L","L","L","S","L","S","S","S","S","L","S","S","L","S","L","S","S","L","S","S","L","S","L","S","S","L","S","S","L","S","L","L","L","S","S","L","L","L","L","S","L","S","L","S","S","S","L","L","L","L","S","S","L","S","S","L","S","S","S","L","S","L","S","S","S","S","S","L","L","S","S","S","L","L","S","L","S","L","S","L","L","S ...

# %% [markdown]
# By looking to the above chart we will find that the ratios of L - M - S is so near to each others so we can play on this by giving some toys or gifts with XL and XXL to increase their sales

# %%
fig = px.pie(df, values=df['category'].value_counts(), names=['Classic','Supreme','Veggie','Chicken'], title='Distribution of each pizza Size in sales',color=['Classic','Supreme','Veggie','Chicken'],  
             color_discrete_map={'Classic':'lightcyan',
                                 'Supreme':'cyan',
                                 'Veggie':'royalblue',
                                 'Chicken':'darkblue'})
fig.show()
# Out:
# <div>                            <div id="704e85cd-70d1-42f4-85d7-2299b41f243b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("704e85cd-70d1-42f4-85d7-2299b41f243b")) {                    Plotly.newPlot(                        "704e85cd-70d1-42f4-85d7-2299b41f243b",                        [{"customdata":[["Classic"],["Supreme"],["Veggie"],["Chicken"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<br>color=%{customdata[0]}<extra></extra>","labels":["Classic","Supreme","Veggie","Chicken"],"legendgroup":"","marker":{"colors":["lightcyan","cyan","royalblue","darkblue"]},"name":"","showlegend":true,"values":[14579,11777,11449,10815],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sca ...

# %%
fig1 = px.histogram(df, x=df['category'])

# %%
fig1.show()
# Out:
# <div>                            <div id="e00ab484-6543-4d2d-af37-3c1e31414b5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e00ab484-6543-4d2d-af37-3c1e31414b5f")) {                    Plotly.newPlot(                        "e00ab484-6543-4d2d-af37-3c1e31414b5f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"category=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic","Classic", ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48620 entries, 0 to 48619
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_details_id    48620 non-null  int64
#  1   order_id            48620 non-null  int64
#  2   pizza_id            48620 non-null  object
#  3   quantity            48620 non-null  int64
#  4   pizza_type_id       48620 non-null  object
#  5   size                48620 non-null  object
#  6   price_of_one_pizza  48620 non-null  float64
#  7   date                48620 non-null  object
#  8   time                48620 non-null  object
#  9   name                48620 non-null  object
#  10  category            48620 non-null  object
#  11  ingredients         48620 non-null  object
#  12  total_price         48620 non-null  float64
#  13  day                 48620 non-null  object
#  14  month               48620 non-null  object
#  15  year                48620 non-null  object
#  16  history             48620 non-null  object
# dtypes: float64(2), int64(3), object(12)
# memory usage: 7.7+ MB

# %%
supreme_price = df[df['category'] == 'Supreme'].total_price.sum()

# %%
classic_price = df[df['category'] == 'Classic'].total_price.sum()

# %%
chicken_price = df[df['category'] == 'Chicken'].total_price.sum()

# %%
veggie_price = df[df['category'] == 'Veggie'].total_price.sum()

# %%
fig = px.pie(price, values=price, names=['supreme price ratio','classic price ratio','chicken price ratio','veggie price ratio'], title='Distribution of each pizza Size in sales',color=['supreme_price','classic_price','chicken_price','veggie_price'],  
             color_discrete_map={'supreme_price':'lightcyan',
                                 'classic_price':'cyan',
                                 'chicken_price':'royalblue',
                                 'veggie_price':'darkblue'})
fig.show()
# Out:
# <div>                            <div id="4791e355-cead-49c7-b46b-1796178bbdf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4791e355-cead-49c7-b46b-1796178bbdf4")) {                    Plotly.newPlot(                        "4791e355-cead-49c7-b46b-1796178bbdf4",                        [{"customdata":[["supreme_price"],["classic_price"],["chicken_price"],["veggie_price"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<br>color=%{customdata[0]}<extra></extra>","labels":["supreme price ratio","classic price ratio","chicken price ratio","veggie price ratio"],"legendgroup":"","marker":{"colors":["lightcyan","cyan","royalblue","darkblue"]},"name":"","showlegend":true,"values":[208197.0,220053.1,195919.5,193690.45],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type ...
